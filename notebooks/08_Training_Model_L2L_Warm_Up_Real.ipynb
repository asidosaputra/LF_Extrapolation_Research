# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
# Out:
# 2025-01-20 14:54:24.411482: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-20 14:54:24.558430: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737359664.614235  105828 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737359664.631832  105828 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-20 14:54:24.764628: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Set up GPU device
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)

# %% [markdown]
# ## 01 Loading Dataset

# %%
def mean_spectrum(data, sampling_rate):
    """
    Plots the normalized mean spectrum of frequency for a 2D seismic shot gather.
    
    Parameters:
    - data: 2D numpy array (time samples x traces), seismic shot gather data.
    - sampling_rate: Sampling rate in Hz (number of samples per second).
    """
    # Number of time samples and traces
    n_samples, n_traces = data.shape
    
    # Fourier transform along the time axis (axis=0)
    fft_data = np.fft.fft(data, axis=0)
    
    # Calculate the frequency axis
    freq = np.fft.fftfreq(n_samples, d=1/sampling_rate)
    
    # Only keep the positive frequencies
    positive_freq = freq[:n_samples // 2]
    positive_fft = fft_data[:n_samples // 2, :]
    
    # Compute the amplitude spectrum
    amplitude_spectrum = np.abs(positive_fft)
    
    # Mean spectrum across all traces
    mean_spectrum = np.mean(amplitude_spectrum, axis=1)
    
    # Normalize the mean spectrum
    # normalized_mean_spectrum = mean_spectrum / np.max(mean_spectrum)

    return positive_freq, mean_spectrum

# %%
raw_data = np.load("../data/datasets/raw_data_real_5Hz.npy")

# %% [markdown]
# QC dataset by ploting sample patches

# %%
import tensorflow as tf
import numpy as np
from scipy import signal

def highpass_filter(data, freq, dt, pad=None):
    """
    Perform high-pass filter on data using SciPy.
    Args:
        freq (float): The cut-off frequency (in Hz).
        data (np.ndarray): Data to be filtered, shape (..., nt, :), where nt = number of time samples.
        dt (float): Time sampling rate of the data (in seconds).
        pad (int, optional): Padding size (before and after, with zeros) before filter.
                             Defaults to None (no padding).
    Returns:
        np.ndarray: High-pass filtered data.
    """
    # Apply padding if specified
    if pad is not None:
        pad_width = [(0, 0)] * (data.ndim - 2) + [(pad, pad), (0, 0)]
        data = np.pad(data, pad_width, mode='reflect')

    # Design the high-pass Butterworth filter
    nyquist = 0.5 / dt  # Nyquist frequency
    sos = signal.butter(8, freq / nyquist, btype='highpass', output='sos')

    # Apply the filter
    filtered_data = signal.sosfiltfilt(sos, data, axis=-2)

    # Remove padding if applied
    if pad is not None:
        filtered_data = filtered_data[..., pad:-pad, :]

    return filtered_data

def preprocess_highpass_filter(data, freq, dt, pad=64):
    """
    TensorFlow wrapper for high-pass filtering using tf.py_function.
    Args:
        data (tf.Tensor): Input data tensor of shape (..., nt, :).
        freq (tuple): Tuple (min_freq, max_freq) defining the range of cutoff frequencies in Hz.
        dt (float): Time sampling interval in seconds.
        pad (int): Padding size for filtering.
    Returns:
        tf.Tensor: Filtered data tensor.
    """
    def filter_fn(data_np):
        # Generate a random frequency within the range
        freq_cut = np.random.uniform(freq[0], freq[1])
        return highpass_filter(data_np, freq_cut, dt, pad)

    # Use tf.py_function to call the filtering function
    filtered_data = tf.py_function(filter_fn, [data], tf.float32)
    # Preserve shape information (important for TensorFlow pipelines)
    filtered_data.set_shape(data.shape)

    return filtered_data
    
    
# Example Parameters
freq = (10, 10)  # High-pass cutoff frequency range in Hz
dt = 4e-3  # Time sampling interval in seconds

# Create separate datasets with independent data copies
label_data = tf.data.Dataset.from_tensor_slices(raw_data)
input_data = tf.data.Dataset.from_tensor_slices(raw_data).map(
    lambda x: preprocess_highpass_filter(x, freq, dt),
    num_parallel_calls=tf.data.AUTOTUNE
)


# Combine Original and Processed Data into a New Dataset
combined_dataset = tf.data.Dataset.zip((input_data, label_data))

# Expand_Dim Batch and Prefetch for Optimization
combined_dataset = combined_dataset.map(lambda x, y: (tf.expand_dims(x, axis=-1), tf.expand_dims(y, axis=-1))).batch(64).prefetch(tf.data.AUTOTUNE)
train_size = int(0.9 * len(combined_dataset))
train_dataset = combined_dataset.take(train_size)
val_dataset = combined_dataset.skip(train_size)
# Out:
# I0000 00:00:1737359675.126278  105828 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9706 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
sample = train_dataset.take(1)
(x, y) = next(sample.as_numpy_iterator())

sampling_rate = 1 / dt
plt.close()
i = 0
for x_sample, y_sample in zip(x, y):
    plt.figure(figsize=(15, 5))
    plt.subplot(1, 3, 1)
    plt.title("Input")
    plt.imshow(x_sample, aspect="auto", cmap="gray")
    plt.colorbar()
    plt.subplot(1, 3, 2)
    plt.title("Label")
    plt.imshow(y_sample, aspect="auto", cmap="gray")
    plt.colorbar()
    plt.subplot(1, 3, 3)
    freq, spect_input = mean_spectrum(np.squeeze(x_sample), sampling_rate)
    freq, spect_output = mean_spectrum(np.squeeze(y_sample), sampling_rate)
    plt.plot(freq, spect_input, label="Input")
    plt.plot(freq, spect_output, label="Label")
    
    plt.xlim(0, 30)
    plt.legend()
    
    i+=1
    if i==5:
        break

# %% [markdown]
# ## 02 Networks Architecture

# %% [markdown]
# ### Define Hybrid Loss Function

# %%
from tensorflow.keras.saving import register_keras_serializable

def amplitude_spectrum_loss(y_true, y_pred):
    # Reshape to ensure proper dimensions for FFT
    y_true = tf.squeeze(y_true, axis=-1)  # Remove the last dimension (128, 128)
    y_pred = tf.squeeze(y_pred, axis=-1)  # Remove the last dimension (128, 128)

    # Perform FFT along the second axis (columns)
    true_spectrum = tf.signal.fft(tf.cast(y_true, tf.complex64))
    pred_spectrum = tf.signal.fft(tf.cast(y_pred, tf.complex64))

    # Compute the amplitude spectrum (magnitude of the complex number)
    true_amplitude = tf.abs(true_spectrum)
    pred_amplitude = tf.abs(pred_spectrum)

    # Return the mean squared error of the amplitude spectrum
    return tf.reduce_mean(tf.square(true_amplitude - pred_amplitude))


@register_keras_serializable()
def hybrid_loss(y_true, y_pred):
    # MAE Loss
    mae_loss = tf.reduce_mean(tf.abs(y_true - y_pred))
    
    # Amplitude Spectrum Loss
    spec_loss = amplitude_spectrum_loss(y_true, y_pred)
    
    # Combine the two losses (you can adjust the weighting factor here)
    total_loss = mae_loss + 0.01 * spec_loss
    return total_loss

# %%
def unet_model_v2(inputs_shape=(None, None, 1)):
    inputs = tf.keras.layers.Input(inputs_shape)

    # Encoder Blocks
    c1 = tf.keras.layers.Conv2D(48, (3, 3), padding='same', activation=None)(inputs)
    c1 = tf.keras.layers.LeakyReLU(alpha=0.1)(c1)
    c1 = tf.keras.layers.Conv2D(48, (3, 3), padding='same', activation=None)(c1)
    c1 = tf.keras.layers.LeakyReLU(alpha=0.1)(c1)
    p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

    c2 = tf.keras.layers.Conv2D(48, (3, 3), padding='same', activation=None)(p1)
    c2 = tf.keras.layers.LeakyReLU(alpha=0.1)(c2)
    p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

    c3 = tf.keras.layers.Conv2D(48, (3, 3), padding='same', activation=None)(p2)
    c3 = tf.keras.layers.LeakyReLU(alpha=0.1)(c3)
    p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

    c4 = tf.keras.layers.Conv2D(48, (3, 3), padding='same', activation=None)(p3)
    c4 = tf.keras.layers.LeakyReLU(alpha=0.1)(c4)
    p4 = tf.keras.layers.MaxPooling2D((2, 2))(c4)

    c5 = tf.keras.layers.Conv2D(48, (3, 3), padding='same', activation=None)(p4)
    c5 = tf.keras.layers.LeakyReLU(alpha=0.1)(c5)
    p5 = tf.keras.layers.MaxPooling2D((2, 2))(c5)

    # Bottleneck
    b = tf.keras.layers.Conv2D(48, (3, 3), padding='same', activation=None)(p5)
    b = tf.keras.layers.LeakyReLU(alpha=0.1)(b)
    b = tf.keras.layers.UpSampling2D((2, 2))(b)

    # Decoder Blocks
    d4 = tf.keras.layers.Concatenate()([b, c5])
    d4 = tf.keras.layers.Conv2D(96, (3, 3), padding='same', activation=None)(d4)
    d4 = tf.keras.layers.LeakyReLU(alpha=0.1)(d4)
    d4 = tf.keras.layers.UpSampling2D((2, 2))(d4)

    d3 = tf.keras.layers.Concatenate()([d4, c4])
    d3 = tf.keras.layers.Conv2D(96, (3, 3), padding='same', activation=None)(d3)
    d3 = tf.keras.layers.LeakyReLU(alpha=0.1)(d3)
    d3 = tf.keras.layers.UpSampling2D((2, 2))(d3)

    d2 = tf.keras.layers.Concatenate()([d3, c3])
    d2 = tf.keras.layers.Conv2D(96, (3, 3), padding='same', activation=None)(d2)
    d2 = tf.keras.layers.LeakyReLU(alpha=0.1)(d2)
    d2 = tf.keras.layers.UpSampling2D((2, 2))(d2)

    d1 = tf.keras.layers.Concatenate()([d2, c2])
    d1 = tf.keras.layers.Conv2D(96, (3, 3), padding='same', activation=None)(d1)
    d1 = tf.keras.layers.LeakyReLU(alpha=0.1)(d1)
    d1 = tf.keras.layers.UpSampling2D((2, 2))(d1)

    d0 = tf.keras.layers.Concatenate()([d1, c1])
    d0 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation=None)(d0)
    d0 = tf.keras.layers.LeakyReLU(alpha=0.1)(d0)
    d0 = tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation=None)(d0)
    d0 = tf.keras.layers.LeakyReLU(alpha=0.1)(d0)

    # Output
    outputs = tf.keras.layers.Conv2D(1, (3, 3), padding='same', activation=None)(d0)

    return tf.keras.Model(inputs, outputs)

# model = unet_model_v2()
    
filename = "Model_SSL_v11_syn_100_epoch_max_9_epoch"
model = tf.keras.models.load_model(f"/mnt/d/01_Project/00_LF_Extrapolation_Research/models/{filename}.keras", compile=False)

# model.summary()

# %%
# Define a learning rate schedule function
def lr_schedule(epoch, lr):
    if epoch < 20:
        return lr
    else:
        return lr * 0.7  # Reduce it further after epoch 10

# Define the callback
lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), loss=hybrid_loss, metrics=['mae'])

model_name = "Warm_Up_50epoch_Real_v0"
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath= f"/mnt/d/01_Project/00_LF_Extrapolation_Research/models/{model_name}.keras",
    monitor='mae',
    save_best_only=True,
    verbose=1,
)

model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,  
    callbacks=[checkpoint_callback, lr_scheduler],
    verbose=1
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/50
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1737359683.416041  105943 service.cc:148] XLA service 0x7f3b7c002b10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1737359683.424596  105943 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-01-20 14:54:43.772686: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1737359684.995234  105943 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-01-20 14:54:55.683962: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[64,144,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,64,128,128]{3,2,1,0}, f32[64,144,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-01-20 14:54:55.744986: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.061067593s
# Trying algorithm eng0{} for conv (f32[64,144,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,64,128,128]{3,2,1,0}, f32[64,144,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-01-20 14:55:04.258995: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng48{k0=9,k2=4,k5=2,k14=3} for conv (f32[48,48,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,48,64,64]{3,2,1,0}, f32[64,48,64,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-01-20 14:55:04.276048: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.356188s
# Trying algorithm eng48{k0=9,k2=4,k5=2,k14=3} for conv (f32[48,48,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,48,64,64]{3,2,1,0}, f32[64,48,64,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
#   1/197 ━━━━━━━━━━━━━━━━━━━━ 1:45:11 32s/step - loss: 0.2041 - mae: 0.1179
# I0000 00:00:1737359713.239144  105943 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - loss: 0.1021 - mae: 0.0651
# Epoch 1: mae improved from inf to 0.04738, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 182s 763ms/step - loss: 0.1019 - mae: 0.0650 - val_loss: 0.0378 - val_mae: 0.0329 - learning_rate: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 2/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - loss: 0.0356 - mae: 0.0311
# Epoch 2: mae improved from 0.04738 to 0.02934, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 147s 746ms/step - loss: 0.0355 - mae: 0.0311 - val_loss: 0.0351 - val_mae: 0.0307 - learning_rate: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 3/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - loss: 0.0295 - mae: 0.0264
# Epoch 3: mae improved from 0.02934 to 0.02505, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 147s 747ms/step - loss: 0.0295 - mae: 0.0264 - val_loss: 0.0266 - val_mae: 0.0240 - learning_rate: 0.0010
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 4/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - loss: 0.0246 - mae: 0.0225
# Epoch 4: mae improved from 0.02505 to 0.02209, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 153s 778ms/step - loss: 0.0246 - mae: 0.0225 - val_loss: 0.0235 - val_mae: 0.0215 - learning_rate: 0.0010
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 5/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - loss: 0.0232 - mae: 0.0212
# Epoch 5: mae improved from 0.02209 to 0.02040, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 146s 743ms/step - loss: 0.0231 - mae: 0.0211 - val_loss: 0.0221 - val_mae: 0.0202 - learning_rate: 0.0010
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 6/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - loss: 0.0208 - mae: 0.0192
# Epoch 6: mae improved from 0.02040 to 0.01868, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 166s 844ms/step - loss: 0.0208 - mae: 0.0192 - val_loss: 0.0199 - val_mae: 0.0184 - learning_rate: 0.0010
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 7/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 0.0190 - mae: 0.0177
# Epoch 7: mae improved from 0.01868 to 0.01768, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 149s 754ms/step - loss: 0.0190 - mae: 0.0177 - val_loss: 0.0195 - val_mae: 0.0180 - learning_rate: 0.0010
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 8/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 0.0191 - mae: 0.0177
# Epoch 8: mae improved from 0.01768 to 0.01715, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 153s 775ms/step - loss: 0.0191 - mae: 0.0177 - val_loss: 0.0188 - val_mae: 0.0174 - learning_rate: 0.0010
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 9/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 0.0178 - mae: 0.0166
# Epoch 9: mae improved from 0.01715 to 0.01621, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 148s 752ms/step - loss: 0.0178 - mae: 0.0166 - val_loss: 0.0179 - val_mae: 0.0167 - learning_rate: 0.0010
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 10/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - loss: 0.0179 - mae: 0.0166
# Epoch 10: mae did not improve from 0.01621
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 152s 773ms/step - loss: 0.0179 - mae: 0.0166 - val_loss: 0.0166 - val_mae: 0.0155 - learning_rate: 0.0010
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 11/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - loss: 0.0179 - mae: 0.0165
# Epoch 11: mae did not improve from 0.01621
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 149s 759ms/step - loss: 0.0179 - mae: 0.0165 - val_loss: 0.0174 - val_mae: 0.0162 - learning_rate: 0.0010
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 12/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - loss: 0.0163 - mae: 0.0153
# Epoch 12: mae improved from 0.01621 to 0.01485, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 146s 741ms/step - loss: 0.0163 - mae: 0.0153 - val_loss: 0.0155 - val_mae: 0.0146 - learning_rate: 0.0010
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 13/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 0.0152 - mae: 0.0144
# Epoch 13: mae improved from 0.01485 to 0.01426, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 150s 762ms/step - loss: 0.0152 - mae: 0.0144 - val_loss: 0.0157 - val_mae: 0.0148 - learning_rate: 0.0010
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 14/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - loss: 0.0157 - mae: 0.0148
# Epoch 14: mae did not improve from 0.01426
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 149s 756ms/step - loss: 0.0157 - mae: 0.0148 - val_loss: 0.0161 - val_mae: 0.0151 - learning_rate: 0.0010
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 15/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - loss: 0.0157 - mae: 0.0147
# Epoch 15: mae did not improve from 0.01426
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 146s 741ms/step - loss: 0.0157 - mae: 0.0147 - val_loss: 0.0171 - val_mae: 0.0159 - learning_rate: 0.0010
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 16/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 0.0145 - mae: 0.0137
# Epoch 16: mae improved from 0.01426 to 0.01363, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 157s 779ms/step - loss: 0.0145 - mae: 0.0137 - val_loss: 0.0149 - val_mae: 0.0140 - learning_rate: 0.0010
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 17/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - loss: 0.0149 - mae: 0.0141
# Epoch 17: mae did not improve from 0.01363
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 154s 781ms/step - loss: 0.0149 - mae: 0.0141 - val_loss: 0.0151 - val_mae: 0.0142 - learning_rate: 0.0010
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 18/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - loss: 0.0140 - mae: 0.0133
# Epoch 18: mae improved from 0.01363 to 0.01319, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 159s 809ms/step - loss: 0.0140 - mae: 0.0133 - val_loss: 0.0141 - val_mae: 0.0134 - learning_rate: 0.0010
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 19/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - loss: 0.0151 - mae: 0.0141
# Epoch 19: mae did not improve from 0.01319
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 151s 770ms/step - loss: 0.0151 - mae: 0.0141 - val_loss: 0.0155 - val_mae: 0.0146 - learning_rate: 0.0010
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 20/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - loss: 0.0143 - mae: 0.0135
# Epoch 20: mae improved from 0.01319 to 0.01312, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 150s 763ms/step - loss: 0.0143 - mae: 0.0135 - val_loss: 0.0160 - val_mae: 0.0150 - learning_rate: 0.0010
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0007000000332482159.
# Epoch 21/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - loss: 0.0134 - mae: 0.0128
# Epoch 21: mae improved from 0.01312 to 0.01239, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 157s 798ms/step - loss: 0.0134 - mae: 0.0128 - val_loss: 0.0148 - val_mae: 0.0140 - learning_rate: 7.0000e-04
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0004900000232737511.
# Epoch 22/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - loss: 0.0124 - mae: 0.0118
# Epoch 22: mae improved from 0.01239 to 0.01159, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 149s 756ms/step - loss: 0.0124 - mae: 0.0118 - val_loss: 0.0137 - val_mae: 0.0130 - learning_rate: 4.9000e-04
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.00034300000406801696.
# Epoch 23/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 0.0117 - mae: 0.0113
# Epoch 23: mae improved from 0.01159 to 0.01111, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 148s 755ms/step - loss: 0.0117 - mae: 0.0113 - val_loss: 0.0136 - val_mae: 0.0129 - learning_rate: 3.4300e-04
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.00024009999469853935.
# Epoch 24/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - loss: 0.0114 - mae: 0.0110
# Epoch 24: mae improved from 0.01111 to 0.01081, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 149s 760ms/step - loss: 0.0114 - mae: 0.0110 - val_loss: 0.0130 - val_mae: 0.0124 - learning_rate: 2.4010e-04
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.00016806999628897755.
# Epoch 25/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - loss: 0.0111 - mae: 0.0107
# Epoch 25: mae improved from 0.01081 to 0.01059, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 145s 736ms/step - loss: 0.0111 - mae: 0.0107 - val_loss: 0.0128 - val_mae: 0.0122 - learning_rate: 1.6807e-04
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.00011764899536501615.
# Epoch 26/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - loss: 0.0108 - mae: 0.0105
# Epoch 26: mae improved from 0.01059 to 0.01043, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 148s 750ms/step - loss: 0.0108 - mae: 0.0105 - val_loss: 0.0127 - val_mae: 0.0121 - learning_rate: 1.1765e-04
#
# Epoch 27: LearningRateScheduler setting learning rate to 8.235429777414538e-05.
# Epoch 27/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - loss: 0.0107 - mae: 0.0104
# Epoch 27: mae improved from 0.01043 to 0.01031, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 151s 769ms/step - loss: 0.0107 - mae: 0.0104 - val_loss: 0.0126 - val_mae: 0.0120 - learning_rate: 8.2354e-05
#
# Epoch 28: LearningRateScheduler setting learning rate to 5.76480058953166e-05.
# Epoch 28/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 0.0106 - mae: 0.0103
# Epoch 28: mae improved from 0.01031 to 0.01022, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 147s 746ms/step - loss: 0.0106 - mae: 0.0103 - val_loss: 0.0125 - val_mae: 0.0119 - learning_rate: 5.7648e-05
#
# Epoch 29: LearningRateScheduler setting learning rate to 4.0353603617404586e-05.
# Epoch 29/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - loss: 0.0105 - mae: 0.0102
# Epoch 29: mae improved from 0.01022 to 0.01015, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 148s 752ms/step - loss: 0.0105 - mae: 0.0102 - val_loss: 0.0124 - val_mae: 0.0119 - learning_rate: 4.0354e-05
#
# Epoch 30: LearningRateScheduler setting learning rate to 2.8247522277524694e-05.
# Epoch 30/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - loss: 0.0105 - mae: 0.0101
# Epoch 30: mae improved from 0.01015 to 0.01010, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 148s 752ms/step - loss: 0.0105 - mae: 0.0101 - val_loss: 0.0124 - val_mae: 0.0119 - learning_rate: 2.8248e-05
#
# Epoch 31: LearningRateScheduler setting learning rate to 1.977326610358432e-05.
# Epoch 31/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - loss: 0.0104 - mae: 0.0101
# Epoch 31: mae improved from 0.01010 to 0.01006, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 147s 748ms/step - loss: 0.0104 - mae: 0.0101 - val_loss: 0.0124 - val_mae: 0.0118 - learning_rate: 1.9773e-05
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.3841286272509023e-05.
# Epoch 32/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - loss: 0.0104 - mae: 0.0101
# Epoch 32: mae improved from 0.01006 to 0.01003, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 147s 748ms/step - loss: 0.0104 - mae: 0.0101 - val_loss: 0.0124 - val_mae: 0.0118 - learning_rate: 1.3841e-05
#
# Epoch 33: LearningRateScheduler setting learning rate to 9.688900263427058e-06.
# Epoch 33/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - loss: 0.0104 - mae: 0.0101
# Epoch 33: mae improved from 0.01003 to 0.01001, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 151s 767ms/step - loss: 0.0104 - mae: 0.0101 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 9.6889e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 6.782229866075795e-06.
# Epoch 34/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - loss: 0.0104 - mae: 0.0100
# Epoch 34: mae improved from 0.01001 to 0.01000, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 147s 750ms/step - loss: 0.0104 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 6.7822e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 4.747560842588427e-06.
# Epoch 35/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 0.0104 - mae: 0.0100
# Epoch 35: mae improved from 0.01000 to 0.00999, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 147s 748ms/step - loss: 0.0104 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 4.7476e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 3.3232926853088427e-06.
# Epoch 36/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 36: mae improved from 0.00999 to 0.00998, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 145s 740ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 3.3233e-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 2.3263049115485044e-06.
# Epoch 37/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 37: mae improved from 0.00998 to 0.00997, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 146s 741ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 2.3263e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 1.6284134062516385e-06.
# Epoch 38/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 38: mae improved from 0.00997 to 0.00997, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 145s 738ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 1.6284e-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 1.1398894002923043e-06.
# Epoch 39/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 39: mae improved from 0.00997 to 0.00997, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 145s 737ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 1.1399e-06
#
# Epoch 40: LearningRateScheduler setting learning rate to 7.979225642884557e-07.
# Epoch 40/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 40: mae improved from 0.00997 to 0.00996, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 144s 733ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 7.9792e-07
#
# Epoch 41: LearningRateScheduler setting learning rate to 5.585457870438403e-07.
# Epoch 41/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 41: mae improved from 0.00996 to 0.00996, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 144s 733ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 5.5855e-07
#
# Epoch 42: LearningRateScheduler setting learning rate to 3.9098203501453095e-07.
# Epoch 42/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 42: mae improved from 0.00996 to 0.00996, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 144s 734ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 3.9098e-07
#
# Epoch 43: LearningRateScheduler setting learning rate to 2.73687416552093e-07.
# Epoch 43/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 43: mae improved from 0.00996 to 0.00996, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 144s 730ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 2.7369e-07
#
# Epoch 44: LearningRateScheduler setting learning rate to 1.915811935759848e-07.
# Epoch 44/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 44: mae improved from 0.00996 to 0.00996, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 145s 736ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 1.9158e-07
#
# Epoch 45: LearningRateScheduler setting learning rate to 1.3410683550318935e-07.
# Epoch 45/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 45: mae improved from 0.00996 to 0.00996, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 144s 734ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 1.3411e-07
#
# Epoch 46: LearningRateScheduler setting learning rate to 9.387478883127187e-08.
# Epoch 46/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 46: mae improved from 0.00996 to 0.00996, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 148s 754ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 9.3875e-08
#
# Epoch 47: LearningRateScheduler setting learning rate to 6.57123521818903e-08.
# Epoch 47/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 47: mae improved from 0.00996 to 0.00996, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 144s 734ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 6.5712e-08
#
# Epoch 48: LearningRateScheduler setting learning rate to 4.599864453780355e-08.
# Epoch 48/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 48: mae improved from 0.00996 to 0.00996, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 146s 740ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 4.5999e-08
#
# Epoch 49: LearningRateScheduler setting learning rate to 3.2199050181702654e-08.
# Epoch 49/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 49: mae improved from 0.00996 to 0.00996, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 147s 748ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 3.2199e-08
#
# Epoch 50: LearningRateScheduler setting learning rate to 2.2539335375881817e-08.
# Epoch 50/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 0.0103 - mae: 0.0100
# Epoch 50: mae improved from 0.00996 to 0.00996, saving model to /mnt/d/01_Project/00_LF_Extrapolation_Research/models/Warm_Up_50epoch_Real_v0.keras
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 147s 749ms/step - loss: 0.0103 - mae: 0.0100 - val_loss: 0.0123 - val_mae: 0.0118 - learning_rate: 2.2539e-08
