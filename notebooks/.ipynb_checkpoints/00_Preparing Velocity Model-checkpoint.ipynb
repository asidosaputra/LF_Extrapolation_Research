# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
p_wave = np.fromfile("/mnt/d/Project/LF_Extrapolation_Research/data/vp.bin", dtype=np.float32).reshape((2301, 751)).T

# %%
plt.imshow(p_wave, aspect="auto")
